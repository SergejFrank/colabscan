# %%
# Check GPU Specs
# !nvidia-smi

# %%
# Get as
# Make a directory called 'dotmasscan' in your Google Drive
from google.colab import drive

# This will ask you to go to a link and get an authorization code
# to let the .hashcat folder get synced to your Google Drive
drive.mount('/content/drive')

# Make a symbolic link between Google Drive
# and the local .hashcat directory
# !ls /content/drive/My\ Drive/dotmasscan
# !ln -s /content/drive/My\ Drive/dotmasscan /root/.masscan

# %%
# Clone, build and install Hashcat
# !apt install cmake build-essential -y

#install masscan
# !git clone https://github.com/robertdavidgraham/masscan /opt/masscan
# !cd /opt/masscan && make && make install

# %%
masscan -iL /root/.masscan/in.txt -p25565 -oL /root/.masscan/out_$(date +%Y-%m-%d-%H-%M).txt --max-rate 10000
